# %%
import pandas as pd

# %%
data = pd.read_csv("output/som_gi_dimensions_name_institution_report.csv")

# %%
data.head()
# Out:
#   faculty/fellow                                              title  \
# 0    Afrin Kamal  Severe gastroparesis is associated with an inc...
# 1    Afrin Kamal  Patient Reported Outcomes and Objective Swallo...
# 2    Afrin Kamal      Type II Achalasia Is Increasing in Prevalence
# 3    Afrin Kamal  Baseline impedance via manometry and ambulator...
# 4    Afrin Kamal  The functional lumen imaging probe in gastroin...
#
#                                          author_list      pmid  \
# 0  Radetic, Mark; Kamal, Afrin; Rouphael, Carol; ...  33231369
# 1  Dewan, Karuna; Clarke, John O.; Kamal, Afrin N...  33103765
# 2  Zhou, Margaret J.; Kamal, Afrin; Freedberg, Da...  33089487
# 3  Zikos, Thomas A; Triadafilopoulos, George; Kam...  33209395
# 4  Clarke, John O.; Ahuja, Nitin K.; Fernandez‐Be...  32814368
#
#     dimensions_id                         doi  \
# 0  pub.1132862420           10.1111/nmo.14045
# 1  pub.1132037180          10.1002/lary.29194
# ...

# %% [markdown]
# ### Get number of publications per faculty/fellow

# %%
pub_count_df = pd.DataFrame()
pub_count_df['faculty/fellow'] = data['faculty/fellow'].unique()
pub_count_df['number of publications'] = data['faculty/fellow'].value_counts()

# %%
pub_count_df
# Out:
#                                        faculty/fellow
# 0                                         Afrin Kamal
# 1                                      Aida Habtezion
# 2                                         Aijaz Ahmed
# 3                                    Alexa Weingarden
# 4                                    Alexander Podboy
# 5                                       Allison Kwong
# 6                                           Andrew Li
# 7                                        Andrew Ofosu
# 8                                          Anson Lowe
# 9                                         Aparna Goel
# 10                                     Branden Tarlow
# 11                                 Chiazotam Ekekezie
# 12                                  Damanpreet Grewal
# 13                                       David Limsui
# 14                                  Deepti Dronamraju
# 15                                            Ed Pham
# ...

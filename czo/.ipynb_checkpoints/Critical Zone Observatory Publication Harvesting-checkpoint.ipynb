# %% [markdown]
# A common problem in encountered when trying to collect a set of publications from multiple researchers (e.g. a network of researchers working on a similar topic or using a shared facility) is the manual labor required to identify and vet the publications. This process often requires a significant exertion of manual labor and is prone to inconsistent results. A typical work flow in carrying out this task is for one or more people to search for publications (e.g. in Google Scholar) and then manually inspect each one to determine relevance. The search component of this process can be automated but, depending on the input available (e.g. the search terms used in the query), it may return a significant number of false positives. The manual labor needed to vet each publication is still too high to be practical. Two questions that will be explored below are: How accurate are the automated searchers? and Can the manual labor needed to vet the publications be reduced?
#
# To explore these questions we will use a set of publications from the Critical Zone Observatory (CZO) website (https://czo-archive.criticalzone.org/reynolds/publications/). The DOIs for the publications were scraped from the sight and used to harvest clean publication records from Dimensions. It is assumed that these publications represent a gold standard dataset that can be used to test other search strategies against.

# %% [markdown]
# To test the quality of our automated search results we collected a list of known grant award numbers related to the CZO network and used these to harvest records from Dimensions. Lets compare the results.

# %%
import fasttext, os, random
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from IPython.display import Markdown, display
from matplotlib_venn import venn2, venn2_circles

# %%
def plot_venn(array_one, array_two, label_one, label_two):
    set1 = set(array_one)
    set2 = set(array_two)

    print("Total: {}".format(len(set1.difference(set2)) + len(set2.difference(set1)) + len(set1.intersection(set2))))

    plt.figure(figsize=(6,4))
    v = venn2(subsets = (len(set1.difference(set2)),
                         len(set2.difference(set1)),
                         len(set1.intersection(set2))), set_labels = (label_one, label_two))
           
    c = venn2_circles(subsets = (len(set1.difference(set2)),
                                 len(set2.difference(set1)),
                                 len(set1.intersection(set2))), linestyle='solid')

    plt.show()

def printmd(string):
    display(Markdown(string))

# %% [markdown]
# ### Compare the two datasets for overlap

# %%
# Load the data harvested from DOIs
from_dois = pd.read_csv('output/output_from_dois.csv', delimiter=',')

# Load the data harvested from award numbers
from_award_numbers = pd.read_csv('output/output_from_award_numbers.csv', delimiter=',')

# %%
plot_venn(from_dois['doi'], from_award_numbers['doi'], 'From DOIs', 'From Award Numbers')
# Out:
# Total: 3921

# %% [markdown]
# Assuming the 'From DOIs' set is both complete and accurate (it has perfect precision and recall), the precision and recall scores for our automated query would be:

# %%
print('Precision = {}'.format(373/(2851+373)))
print('Recall = {}'.format(373/(697+373)))
# Out:
# Precision = 0.11569478908188585
# Recall = 0.3485981308411215

# %% [markdown]
# Not great. As expected there are many false positives. At this point it may be worthwhile to question the completeness of the DOI dataset. It is clear that all of the publications harvested from the CZO site are relevant but it may be a false assumption to think that the set is also complete. We know little about the process through which this list came to exist. To improve recall, we can add more terms to the query, things like site names, grid ids, and rrids come to mind but our already poor precision score would decrease further. Perhaps we can build a training set from the CZO data to train a classifier that we can use to eliminate many of the false positives from our automated query. To do so we can label each publication as 'relevant' or 'not-relevant'. We have 1070 'relevant' publications to start with. We need probably 10 times that number of 'not-relevant' publications, since the set of 'not-relevant' publications needs to include learning examples from all other domains except the earth sciences.

# %% [markdown]
# Lets load a data set of publications gathered from searching random words with strong associations to other domains.

# %%
# Load the data harvested from terms with strong associations to other domains
non_relevant = pd.read_csv('output/not_relevant.csv', delimiter=',')
non_relevant.head()
# Out:
#                                                title  authors              id  \
# 0  Financial Technology Regulation in Malaysia an...      NaN  pub.1137575199
# 1  The Effect of the Installation Angle of the Sk...      NaN  pub.1135344436
# 2  Perancangan Sistem Data Hasil Belajar Murid SM...      NaN  pub.1134641628
# 3  Religious Education Policy in Public Schools D...      NaN  pub.1136673480
# 4  Estimating the oil revenues of Iran premised o...      NaN  pub.1139332393
#
#                                     doi  \
# 0             10.12928/ijiefb.v3i2.2703
# 1               10.12928/irip.v3i2.2074
# 2        10.32493/informatika.v5i4.7675
# 3             10.19105/karsa.v28i2.3936
# 4  10.22363/2313-2329-2021-29-2-451-462
#
#                                   publisher  \
# 0                  Universitas Ahmad Dahlan
# 1                  Universitas Ahmad Dahlan
# 2                      Universitas Pamulang
# 3        Institut Agama Islam Negeri Madura
# 4  Peoples' Friendship University of Russia
#
#                                              journal volume issue    pages  \
# 0  {'id': 'jour.1359381', 'title': 'Ihtifaz Journ...      3     2    67-87
# 1  {'id': 'jour.1377959', 'title': 'Indonesian Re...      3     2    35-39
# 2  {'id': 'jour.1378245', 'title': 'Jurnal Inform...      5     4      592
# 3  {'id': 'jour.1153536', 'title': 'KARSA Journal...     28     2  390-409
# 4  {'id': 'jour.1299696', 'title': 'RUDN Journal ...     29     2  451-462
#
#    pub_year                                           concepts  \
# 0      2021  ['technology regulation', 'lack of jurisdictio...
# 1      2021  ['sky brightness', 'western horizon', 'eastern...
# 2      2021  ['senior high school', 'high school', 'Islamic...
# 3      2021  ['religious education', 'accommodative policy'...
# 4      2021  ['foreign policy', 'bilateral relations', 'pre...
#
#                                             abstract acknowledgements funders  \
# 0  Introduction to The Problem: The era of innova...              NaN     NaN
# 1  Measuring the brightness of the night sky and ...              NaN     NaN
# 2  SMAI Said Na'um is a senior secondary educatio...              NaN     NaN
# 3  The new order government policy about religiou...              NaN     NaN
# 4  The Islamic Revolution of 1979 has filpped Ira...              NaN     NaN
#
#                                  research_org_cities  \
# 0  [{'id': 1735161, 'name': 'Kuala Lumpur'}, {'id...
# 1                 [{'id': 1214520, 'name': 'Medan'}]
# 2                                                NaN
# 3                                                NaN
# 4                 [{'id': 524901, 'name': 'Moscow'}]
#
#                                   research_org_names research_org_state_names  \
# 0  ['IIUM Institute of Islamic Banking and Financ...                      NaN
# 1        ['Universitas Muhammadiyah Sumatera Utara']                      NaN
# 2                                                NaN                      NaN
# 3                                                NaN                      NaN
# 4  ['Diplomatic Academy of the Russian Foreign Mi...                      NaN
#
#                                        research_orgs  provenance  \
# 0  [{'id': 'grid.444626.6', 'types': ['Education'...  dimensions
# 1  [{'id': 'grid.443842.d', 'types': ['Education'...  dimensions
# 2                                                NaN  dimensions
# 3                                                NaN  dimensions
# 4  [{'id': 'grid.445840.9', 'types': ['Education'...  dimensions
#
#     pub_harvested_date
# 0  15/07/2021 09:57:50
# 1  15/07/2021 09:57:50
# 2  15/07/2021 09:57:50
# 3  15/07/2021 09:57:50
# 4  15/07/2021 09:57:50

# %% [markdown]
# The concepts column is what we will use as features for training and prediction. So let's remove any rows where that column is empty then write the concepts tokens to a file adding a 'non-relevant' label in the process.

# %%
def training_data_from_df(df, label, out_file):
    df['concepts'].replace('', np.nan, inplace=True)
    df.dropna(subset=['concepts'], inplace=True)
    np.savetxt('temp.txt', df.concepts, fmt='%s')
    features = open('temp.txt', "r")
    with open('{}'.format(out_file), "w") as out:
        for line in features.readlines():
            out.write('__label__{} {}'.format(label, line.replace("['", "'").replace("']", "'").replace(", ", " ")))
    os.remove('temp.txt')

# %%
training_data_from_df(from_dois, 'relevant', 'output/relevant.txt')

# %%
def merge_files(file_one, file_two, out_file):
    one = open(file_one, "r")
    two = open(file_two, "r")
    with open('{}'.format(out_file), "w") as out:
        for line in one.readlines():
            out.write(line)
        for line in two.readlines():
            out.write(line)

# %%
merge_files('output/relevant.txt', 'output/non-relevant.txt', 'output/earth-sciences.txt')

# %% [markdown]
# Now that we have an initial dataset to train our model, lets break it into training and validation sets and give it a try.

# %%
with open('output/earth-sciences.txt', 'r') as f:
    data = f.read().split('\n')
    print(len(data))

random.shuffle(data)

with open('output/earth-sceinces.train', 'w') as train:
    for i in data[:1400]:
        train.write(i)

with open('output/earth-sceinces.valid', 'w') as valid:
    for i in data[1400:]:
        valid.write(i)
# Out:
# 13840

# %%
model = fasttext.train_supervised(input=train_data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-95-9ff62b65976e> in <module>
# ----> 1 model = fasttext.train_supervised(input=train_data)
#
# ~/miniconda3/envs/py3d/lib/python3.7/site-packages/fasttext/FastText.py in train_supervised(*kargs, **kwargs)
#     529     args, manually_set_args = read_args(kargs, kwargs, arg_names,
#     530                                         supervised_default)
# --> 531     a = _build_args(args, manually_set_args)
#     532     ft = _FastText(args=a)
#     533     fasttext.train(ft.f, a)
#
# ~/miniconda3/envs/py3d/lib/python3.7/site-packages/fasttext/FastText.py in _build_args(args, manually_set_args)
#     420     a = fasttext.args()
#     421     for (k, v) in args.items():
# --> 422         setattr(a, k, v)
#     423         if k in manually_set_args:
#     424             a.setManual(k)
#
# TypeError: (): incompatible function arguments. The following argument types are supported:
#     1. (self: fasttext_pybind.args, arg0: str) -> None
#
# Invoked with: <fasttext_pybind.args object at 0x7fca077c3ea0>, ["__label__non-relevant 'adsorption of palladium' 'aqueous solution' 'chemical co-precipitation method' 'co-precipitation method' 'BET specific surface area' 'Sips model' 'maximum adsorption performance' 'maximum adsorption capacity' 'specific surface area' 'second-order model' 'average pore size' 'kinetic model' 'cumulative pore volume' 'magnetic polymer' 'adsorbent surface' 'chemical adsorption' 'adsorbent characterization' 'adsorption performance' 'diatomite composites' 'adsorption capacity' 'adsorption process' 'pore volume' 'Langmuir model' 'Freundlich model' 'spontaneous sorption' 'exothermic nature' 'adsorption' 'pore size' 'sorption sites' 'surface area' 'palladium' 'contact time' 'sodium alginate' 'palladium concentration' 'response surface methodology' 'thermodynamic data' 'fit isotherm' 'rapid removal' 'experimental data' 'modeling studies' 'polymers' 'solver method' 'low concentrations' 'Fe3O4' 'isotherms' 'sorption' 'composites' 'solution' 'diatomite' 'synthesis' 'surface methodology' 'optimization study' 'molecules' 'concentration' 'high concentrations' 'alginate' 'coefficient of determination' 'pH' 'good agreement' 'nonlinear kinetic model' 'characterization' 'surface' 'average percentage error' 'determination' 'statistical terms' 'root mean square error' 'structure' 'mean square error' 'method' 'residual sum' 'statistical results' 'removal' 'chi-square statistics' 'samples' 'satisfactory adjustment' 'order' 'square error' 'capacity' 'presence' 'nature' 'size' 'percentage error' 'dosage' 'investigation' 'process' 'analysis' 'coefficient' 'results' 'fit model' 'error' 'model' 'sites' 'min' 'agreement' 'study' 'statistics' 'performance' 'volume' 'squares' 'methodology' 'sum' 'time' 'comparison' 'area' 'data' 'terms' 'feasibility' 'imply' 'software' 'ANOVA analysis' 'aim' 'adjustment'", "__label__non-relevant 'education' 'challenges' 'growth' 'society' 'higher education' 'sustainable society' 'composite growth'", "__label__relevant 'forest types' 'exchangeable Ca' 'cation availability' 'parent material' 'El Yunque National Forest' 'primary mineral weathering' 'montane tropical forests' 'degree of soil' 'common forest types' 'Puerto Rico' 'parent rock type' 'tabonuco forest' 'bulk soil' 'exchangeable strontium' 'Ca stocks' 'soil profile' 'forest communities' 'tropical forests' 'exchangeable Mg' 'base cations' 'National Forest' 'mineral weathering' 'Luquillo Mountains' 'exchangeable cations' 'Colorado forest' 'elevation zones' 'atmospheric deposition' 'soil' 'forest' 'atmospheric inputs' 'lower slope' 'last 5Ma' 'stocks' 'weathering' 'isotopic composition' 'geomorphology' 'availability' 'Rico' 'mineral supply' 'underlain' 'region sites' 'toposequence' 'landscape' 'Ca' 'Mountains' 'landforms' 'community' 'most control' 'elevation' 'factorial design' 'Mg' 'geology' 'rock types' 'slope' 'potassium' 'zone' 'Province' 'geologic' 'geologic provinces' 'composition' 'types' 'sites' 'input' 'supply' 'lithology' 'cations' 'variance' 'magnesium' 'knickpoints' 'deposition' 'strontium' 'similar interactions' 'goal' 'factors' 'uplift' 'response' 'interaction' 'degree' 'calcium' 'link' 'profile' 'quartz diorite' 'data' 'control' 'less calcium' 'exerts' 'materials' 'network' 'diorite' 'design' 'volcaniclastics' 'biologics' 'regional uplift'", "__label__non-relevant 'International Accounting Standards Board' 'global harmonization' 'regulatory reform' 'energy policy' 'modernization' 'Accounting Standards Board' 'international comparability' 'professional bodies' 'Securities Commission' 'regulatory changes' 'reporting project' 'Standards Board' 'security' 'securities regulators' 'standard setters' 'harmonization' 'practice' 'reform' 'policy' 'gas reserves' 'jurisdictions' 'policymakers' 'Commission' 'accountancy' 'ecology' 'proposition' 'project' 'reporting rules' 'international standardization' 'professionals' 'questions' 'implications' 'setters' 'rules' 'gap' 'board' 'bod ...

# %%
award_numbers_not_doi = set(from_award_numbers['doi']) - set(from_dois['doi'])
print(len(award_numbers_not_doi))
overlap = set(from_award_numbers['doi']) - set(award_numbers_not_doi)
print(len(overlap))
# Out:
# 2851
# 373

# %%
awards_only = from_award_numbers[~from_award_numbers['doi'].isin(overlap)]
print(awards_only.shape)
# Out:
# (3119, 16)

# %%
awards_only.to_csv('output/award_number_only.csv')

# %% [markdown]
# ### Cleanup 'From Award Numbers' Data

# %% [markdown]
# It is assumed that any publications that were published before the award year are false positives and can safely be removed.

# %% [markdown]
# Is it safe to assume that all true positives will be English publications or, at least, Latin script publications?

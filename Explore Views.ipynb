# %%
import pandas as pd

# %%
data = pd.read_csv("output/som_gi_dimensions_name_institution_report.csv")

# %% [markdown]
# ### Get number of publications per faculty/fellow

# %%
print(data['faculty'].value_counts())
# Out:
# Mindie Nguyen               239
# George Triadafilopoulos     235
# Aijaz Ahmed                 234
# Ramsey Cheung               194
# Shai Friedland              136
# Subhas Banerjee             112
# Uri Ladabaum                111
# Jeffrey Glenn               103
# Aida Habtezion               78
# Walter Park                  77
# John Clarke                  69
# Monique Barakat              63
# Nielsen Fernandez-Becker     56
# Robert J Huang               51
# Linda Nguyen                 51
# Andrew Li                    44
# Joo Ha Hwang                 43
# Paul Kwo                     39
# Anson Lowe                   38
# Jennifer Pan                 26
# Thomas Zikos                 23
# Alexander Podboy             21
# Sidhartha R Sinha            20
# Afrin Kamal                  19
# Tami Daugherty               19
# Allison Kwong                19
# Patricia Garcia              18
# Stephan Rogalla              16
# Aparna Goel                  15
# ...

# %% [markdown]
# ### Get common co-authors

# %%
data['author_list'].groupby(data['faculty']).head()
# Out:
# 0       Radetic, Mark; Kamal, Afrin; Rouphael, Carol; ...
# 1       Dewan, Karuna; Clarke, John O.; Kamal, Afrin N...
# 2       Zhou, Margaret J.; Kamal, Afrin; Freedberg, Da...
# 3       Zikos, Thomas A; Triadafilopoulos, George; Kam...
# 4       Clarke, John O.; Ahuja, Nitin K.; Fernandez‐Be...
# 19      Swaminathan, Gayathri; Nguyen, Linh P.; Namkoo...
# 20      Wei, Lai; Singh, Rajan; Ha, Se Eun; Martin, Al...
# 21      Gubatan, John; Sinha, Sidhartha R; Habtezion, ...
# 22      Ha, Seeun; Jin, Byungchang; Clemmensen, Brooke...
# 23      Bai, Lawrence; Scott, Madeleine KD; Steinberg,...
# 97      Kim, Donghee; Wijarnpreecha, Karn; Sandhu, Kee...
# 98      Alshuwaykh, Omar; Kwong, Allison; Goel, Aparna...
# 99      Abdallah, Mohamed A; Kuo, Yong-Fang; Asrani, S...
# 100     Adeniji, Nia; Arjunan, Vinodhini; Prabhakar, V...
# 101     Kulkarni, Chiraag; Murag, Soumya; Cholankeril,...
# 331     Weingarden, Alexa R.; Villescas, Victoria; Cla...
# ...
